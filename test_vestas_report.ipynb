# %%
from classes import Vestas_Report; from pathlib import Path

folder_path = "data"
file_name = 'vestas_report_example.pdf'
file_path = Path(folder_path) / file_name
# Out:
# c:\Users\dbreau\Documents\Repositories\pdf_transformation\venv\Lib\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
vestas_report = Vestas_Report(file_path)

# %%
vestas_report.get_header_informations()
# Out:
# {'turbine_number': '232',
#  'service_order': '6114',
#  'pad_no': 'HOU',
#  'turbine_type': 'V136',
#  'start_date': '17.10.2023',
#  'customer_address': ['ENERGIE'],
#  'date_and_time_of_receipt': '19.03.2023 22:15:02',
#  'reason_for_call_out': 'Check ICPE Electrical V136'}

# %%
import pandas as pd; pd.set_option('display.max_rows', None); pd.set_option('display.max_columns', None); pd.set_option('display.width', None); pd.set_option('display.max_colwidth', None) 

full_table=vestas_report._extract_full_table()

# %%
full_table
# Out:
#                           0  \
# 0
# 1   Service Inspection Form
# 2                      0010
# 3                         0
# 4                      0.01
# 5                         1
# 6                      1.01
# 7                      1.02
# 8
# 9
# 10                     1.03
# 11
# 12
# 13
# 14                     1.04
# 15                     1.05
# 16                     1.06
# 17                        2
# 18                     2.01
# 19
# 20                     2.02
# 21
# 22
# 23                     2.03
# 24
# 25                        3
# 26                     3.01
# 27                     3.02
# 28
# 29
# 30                     3.03
# 31                     3.04
# 32
# 33
# 34
# 35                     3.05
# 36
# 37                     3.06
# 38
# 39
# 40
# 41                     3.07
# 42
# 43                        4
# 44                     4.01
# 45
# 46
# 47                     4.02
# 48                     4.03
# 49                     4.04
# 50
# 51                     4.05
# 52                     4.06
# 53
# 54
# 55
# 56
# 57                     4.07
# 58                     4.08
# 59
# 60
#
#                                                                                                                 1  \
# 0
# 1
# 2                                                                                  Check ICPE Electrical V112-3MW
# 3                                                                                                            eSIF
# 4                                                                                           0. DMS: 0093-0083 V03
# 5                                                                                                          Safety
# 6         Two persons present.                                                                                 OK
# 7                                           Trained in and aware of the contents of the Vestas Corporate OH and S
# 8                                                  Manual including ‘Working with Hazardous Materials’ and Safety
# 9                                                                      Regulations for Operators and Technicians.
# 10                                            Be sure to know the general recommendations regarding the following
# 11                                            points: For safety reasons, note the location of the emergency stop
# 12                                                 buttons. Please refer to documentation “Safety Regulations for
# 13                                              Operators and Technicians” of the corresponding turbine platform.
# 14       Locking of rotor/blades.                                                                              OK
# 15     Hearing protection.                                                                                     OK
# 16  Hydraulic tools.                                                                                           OK
# 17                                                                                                     Article 16
# 18                                                  Check that wind turbine is clean. Check that nocombustible or
# 19                                                        inflammable material is stored inside the wind turbine.
# 20                                           L'intérieur de l'aérogénérateur est maintenu propre. L'entreposage à
# 21                                                   l'intérieur de l'aérogénérateur de matériaux combustibles ou
# 22                                                                                     inflammables est interdit.
# 23                                                                                        Remarks: (as a comment)
# 24
# 25                                                                                                     Article 17
# 26                Verify Stop Button is working properly.                                                      OK
# 27                                     Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise des
# 28                                    tests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt en
# 29                                            application des préconisations du constructeur de l'aérogénérateur.
# 30                         Verify Emergency Stop Button is working properly.                                   OK
# 31                                     Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise des
# 32                                       tests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt
# 33                                                 d'urgence en application des préconisations du constructeur de
# 34                                                                                              l'aérogénérateur.
# 35                                                             Perform a VOG Test based on relevant platform SWI.
# 36
# 37                                     Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise des
# 38                                       tests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt
# 39                                            depuis un régime de survitesse en application des préconisations du
# 40                                                                               constructeur de l'aérogénérateur
# 41                                                                                        Remarks: (as a comment)
# 42
# 43                                                                                                 Article 18 III
# 44                                            Contrôle des systèmes instrumentés de sécurité: Selon une fréquence
# 45                                             qui ne peut excéder un an, l’exploitant procède au contrôle de ces
# 46                                         équipements de sécurités afin de s’assurer de leur bon fonctionnement.
# 47    Control of UPS                                                                                           OK
# 48                       Contrôle du bon fonctionnement de l’onduleur                                          OK
# 49                                               Control of correct condition (absence of leakage or damages) and
# 50                                                                              correct behavior of Pitch System.
# 51                                     Contrôle du bon fonctionnement du système d’orientation des pales       OK
# 52                                             Control of good behavior of Smoke Detector systems. Check that log
# 53                                        “smoke detected” is registered in turbine controller (see operation log
# 54                                                                                                          menu)
# 55
# 56
# 57                                    Si installés, contrôle du bon fonctionnement des détecteurs de fumée     OK
# 58                                                                                        Remarks: (as a comment)
# 59
# 60                                                                                                    Page 4 of 4
#
#                           2                        3
# 0                    232085                 61140280
# 1
# 2
# 3
# 4
# 5
# 6
# 7                        OK
# 8
# 9
# 10                       OK
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18                       OK
# 19
# 20                       OK
# 21
# 22
# 23
# 24                                    Not Applicable
# 25
# 26
# 27                       OK
# 28
# 29
# 30
# 31                       OK
# 32
# 33
# 34
# 35
# 36                                    Not Applicable
# 37                       OK
# 38
# 39
# 40
# 41
# 42                                    Not Applicable
# 43
# 44                       OK
# 45
# 46
# 47
# 48
# 49                       OK
# 50
# 51
# 52                       OK
# 53
# 54
# 55                                    Service Report
# 56  Turbine No./Id:\n232085  Service order\n61140280
# 57
# 58
# 59                                    Not Applicable
# 60

# %%
vestas_report.check_column_lines(2)
